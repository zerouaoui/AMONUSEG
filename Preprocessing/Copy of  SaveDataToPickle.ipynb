# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
############################################ Functions ############################################

# This function takes 1 parameter: the  dimension(img_dim)
# and return as a tupel of numpy arrays (data and its labels)
def load_data_to_np( img_dim):
  images = []
  masks = []
  dataset = 'Monuseg'
  dirs = ['M_Augmented', 'Masks']

  #hcange the path with th data
  cpath=  '/content/drive/My Drive/MICCAI Project/'+dataset+'/M_augmented'
  # this loop has 2 iterations: first iteration loads 'B' images and gives them 0 as label
  # and second loads 'M' images and gives them label 1
  for files_dir in dirs:
    files_= glob.glob(os.path.join(cpath, files_dir, "*"))
    for img in files_:
      img = Image.open(images)
      img = img.resize( img_dim )
      img = img.convert("RGB")
      img1 = np.array(img) / 255.
      data.append(img1)
  #convert the lists to a numpy array
  data = np.asarray(images)
  label = np.asarray(masks)
  return images, masks

# %%
# save data and its labels to a pickle files
# because the first function takes a lot of time and cosumes RAM
# so to avoid recalling it i save the numpy arrays to files, this way i reload data so fast
def save_data_labels_to_pickle(images, masks, dataset, img_dim):
  cpath=  '/content/drive/My Drive/MICCAI Project/'+dataset+'/M_augmented'
  with open('/content/drive/My Drive/MICCAI Project/Pickle/'+dataset+'/data_'+dataset+'_'+str(img_dim[0])+'.pickle', 'wb') as handle:
    pickle.dump(images, handle, protocol=pickle.HIGHEST_PROTOCOL)
  with open('/content/drive/My Drive/Colab/pickle/'+dataset+'/data_Masks_'+dataset+'_'+str(img_dim[0])+'.pickle', 'wb') as handle:
    pickle.dump(masks, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
from PIL import Image
import numpy as np
import itertools
import os
import glob
import pickle

#res_299= (299, 299)
res_224= (224, 224)

# %%
# Loading Images
#data_299, label_299= load_data_to_np( res_299)
data_224, label_224= load_data_to_np(res_224)
dataset="Monuseg"

# saving to pickle files
#save_data_labels_to_pickle(data_299, label_299,  res_299)
save_data_labels_to_pickle(data_224, label_224,  dataset,  res_224)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-652dbf54f940> in <cell line: 8>()
#       6 # saving to pickle files
#       7 #save_data_labels_to_pickle(data_299, label_299,  res_299)
# ----> 8 save_data_labels_to_pickle(data_224, label_224,  dataset,  res_224)
#
# <ipython-input-28-0bb1fd9ea059> in save_data_labels_to_pickle(images, masks, dataset, img_dim)
#       4 def save_data_labels_to_pickle(images, masks, dataset, img_dim):
#       5   cpath=  '/content/drive/My Drive/MICCAI Project/'+dataset+'/M_augmented'
# ----> 6   with open('/content/drive/My Drive/MICCAI Project/Pickle/'+dataset+'/data_'+dataset+'_'+str(img_dim[0])+'.pickle', 'wb') as handle:
#       7     pickle.dump(images, handle, protocol=pickle.HIGHEST_PROTOCOL)
# ...

# %%
data_224
# Out:
# array([[[[0.45098039, 0.43529412, 0.50196078],
#          [0.19607843, 0.17647059, 0.24313725],
#          [0.14117647, 0.10196078, 0.18039216],
#          ...,
#          [0.17647059, 0.14509804, 0.19215686],
#          [0.19215686, 0.16470588, 0.21568627],
#          [0.18431373, 0.16078431, 0.20392157]],
#
#         [[0.19607843, 0.18431373, 0.23529412],
#          [0.1372549 , 0.11372549, 0.17254902],
#          [0.16078431, 0.11764706, 0.19215686],
#          ...,
#          [0.17647059, 0.14117647, 0.19215686],
#          [0.18039216, 0.15686275, 0.2       ],
#          [0.17254902, 0.15686275, 0.18039216]],
#
#         [[0.17647059, 0.15294118, 0.20784314],
#          [0.15294118, 0.12156863, 0.19215686],
#          [0.23137255, 0.18431373, 0.2627451 ],
#          ...,
#          [0.43921569, 0.38823529, 0.43529412],
#          [0.38823529, 0.35686275, 0.39607843],
#          [0.26666667, 0.25098039, 0.25490196]],
#
#         ...,
#
# ...
