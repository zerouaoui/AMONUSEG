# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/'My Drive'/'MICCAI Project'/
# Out:
# /content/drive/My Drive/MICCAI Project

# %%
pip install torchstain
# Out:
# Collecting torchstain
#   Downloading torchstain-1.3.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchstain) (1.23.5)
# Installing collected packages: torchstain
# Successfully installed torchstain-1.3.0

# %%
import torch
import os
from torchvision import transforms
import torchstain
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
#Datasets to process
#Dataset = 'Cryonuseg'
#Dataset = 'TNBC'
Dataset = 'Monuseg'
#Dataset = 'Africa'

#Input and output folders
folder_path = '/content/drive/My Drive/MICCAI Project/'+Dataset+'/Images'
output_folder = '/content/drive/My Drive/MICCAI Project/'+Dataset+'/Reinhard'

# %%
#define the Macenko Normlizer using torchvision
def reinhard_normalization(image):
  target = cv2.cvtColor(cv2.imread('/content/drive/My Drive/MICCAI Project/target.png'), cv2.COLOR_BGR2RGB)
  T = transforms.Compose([
      transforms.ToTensor(),
      transforms.Lambda(lambda x: x*255)
      ])
  normalizer = torchstain.normalizers.ReinhardNormalizer(backend='torch')
  normalizer.fit(T(target))
  t_to_transform = T(image)
  norm= normalizer.normalize(I=t_to_transform)
  return norm

# %%
# Loop through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.tif') or filename.endswith('.jpg') or filename.endswith('.png'):
        # Read the image
        image_path = os.path.join(folder_path, filename)
        image = cv2.imread(image_path)


        # Apply Macenko normalization
        normalized_image = reinhard_normalization(image)
        normalized_image = np.asarray(normalized_image)

        # Save the normalized image
        save_path = os.path.join(output_folder, f'{filename}')
        cv2.imwrite(save_path, normalized_image)

        print(f"Normalized image '{filename}' saved as '{filename}'")

print("Normalization process completed for all images.")
# Out:
# Normalized image 'TCGA-21-5784-01Z-00-DX1.png' saved as 'TCGA-21-5784-01Z-00-DX1.png'
# Normalized image 'TCGA-21-5786-01Z-00-DX1.png' saved as 'TCGA-21-5786-01Z-00-DX1.png'
# Normalized image 'TCGA-38-6178-01Z-00-DX1.png' saved as 'TCGA-38-6178-01Z-00-DX1.png'
# Normalized image 'TCGA-49-4488-01Z-00-DX1.png' saved as 'TCGA-49-4488-01Z-00-DX1.png'
# Normalized image 'TCGA-50-5931-01Z-00-DX1.png' saved as 'TCGA-50-5931-01Z-00-DX1.png'
# Normalized image 'TCGA-A7-A13E-01Z-00-DX1.png' saved as 'TCGA-A7-A13E-01Z-00-DX1.png'
# Normalized image 'TCGA-A7-A13F-01Z-00-DX1.png' saved as 'TCGA-A7-A13F-01Z-00-DX1.png'
# Normalized image 'TCGA-AR-A1AK-01Z-00-DX1.png' saved as 'TCGA-AR-A1AK-01Z-00-DX1.png'
# Normalized image 'TCGA-AR-A1AS-01Z-00-DX1.png' saved as 'TCGA-AR-A1AS-01Z-00-DX1.png'
# Normalized image 'TCGA-B0-5698-01Z-00-DX1.png' saved as 'TCGA-B0-5698-01Z-00-DX1.png'
# Normalized image 'TCGA-B0-5710-01Z-00-DX1.png' saved as 'TCGA-B0-5710-01Z-00-DX1.png'
# Normalized image 'TCGA-B0-5711-01Z-00-DX1.png' saved as 'TCGA-B0-5711-01Z-00-DX1.png'
# Normalized image 'TCGA-CH-5767-01Z-00-DX1.png' saved as 'TCGA-CH-5767-01Z-00-DX1.png'
# Normalized image 'TCGA-DK-A2I6-01A-01-TS1.png' saved as 'TCGA-DK-A2I6-01A-01-TS1.png'
# Normalized image 'TCGA-G2-A2EK-01A-02-TSB.png' saved as 'TCGA-G2-A2EK-01A-02-TSB.png'
# Normalized image 'TCGA-G9-6336-01Z-00-DX1.png' saved as 'TCGA-G9-6336-01Z-00-DX1.png'
# Normalized image 'TCGA-G9-6348-01Z-00-DX1.png' saved as 'TCGA-G9-6348-01Z-00-DX1.png'
# Normalized image 'TCGA-G9-6356-01Z-00-DX1.png' saved as 'TCGA-G9-6356-01Z-00-DX1.png'
# Normalized image 'TCGA-G9-6362-01Z-00-DX1.png' saved as 'TCGA-G9-6362-01Z-00-DX1.png'
# Normalized image 'TCGA-HE-7128-01Z-00-DX1.png' saved as 'TCGA-HE-7128-01Z-00-DX1.png'
# Normalized image 'TCGA-HE-7130-01Z-00-DX1.png' saved as 'TCGA-HE-7130-01Z-00-DX1.png'
# Normalized image 'TCGA-KB-A93J-01A-01-TS1.png' saved as 'TCGA-KB-A93J-01A-01-TS1.png'
# Normalized image 'TCGA-NH-A8F7-01A-01-TS1.png' saved as 'TCGA-NH-A8F7-01A-01-TS1.png'
# Normalized image 'TCGA-RD-A8N9-01A-01-TS1.png' saved as 'TCGA-RD-A8N9-01A-01-TS1.png'
# Normalized image 'TCGA-18-5592-01Z-00-DX1.png' saved as 'TCGA-18-5592-01Z-00-DX1.png'
# Normalized image 'TCGA-AY-A8YK-01A-01-TS1.png' saved as 'TCGA-AY-A8YK-01A-01-TS1.png'
# Normalized image 'TCGA-E2-A14V-01Z-00-DX1.png' saved as 'TCGA-E2-A14V-01Z-00-DX1.png'
# Normalized image 'TCGA-E2-A1B5-01Z-00-DX1.png' saved as 'TCGA-E2-A1B5-01Z-00-DX1.png'
# Normalized image 'TCGA-G9-6363-01Z-00-DX1.png' saved as 'TCGA-G9-6363-01Z-00-DX1.png'
# Normalized image 'TCGA-HE-7129-01Z-00-DX1.png' saved as 'TCGA-HE-7129-01Z-00-DX1.png'
# Normalization process completed for all images.
